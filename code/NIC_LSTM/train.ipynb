# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import json
import os
import datetime
import time
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.python.keras.callbacks import TensorBoard

# %%
# 데이터 불러오기

train_x_path = "../../data/use_data/train_x.npy"
test_x_path = "../../data/use_data/test_x.npy"
train_y_path = "../../data/use_data/train_y.npy"
test_y_path = "../../data/use_data/test_y.npy"

x_train = np.load(train_x_path) 
y_train = np.load(train_y_path) 
x_test = np.load(test_x_path) 
y_test = np.load(test_y_path)

# %%
##### 하이퍼 파라미터 설정
hp = {"n_most_common_words": 100000,
       "emb_dim": 128,
        "dropput":0.2,
        "epochs":100,
        "batch_size":64,
        "activation_function":"softmax",
        "max_len": 10}

# %%
def train(train_x, train_y, hp):

    model_path = "../../model/model.h5"
    log_path = "../../model/logs"
    
    model = Sequential()
    model.add(Embedding(hp["n_most_common_words"], hp["emb_dim"], input_length=hp["max_len"]))
    model.add(SpatialDropout1D(hp["dropput"]))
    model.add(LSTM(64, dropout=hp["dropput"], recurrent_dropout=hp["dropput"]))
    model.add(Dense(train_y.shape[1], activation=hp['activation_function']))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
    mc = ModelCheckpoint(model_path, monitor = 'val_acc', mode='max', verbose=1, save_best_only=True)
    tb = TensorBoard(log_dir=log_path)
    
    history = model.fit(train_x, train_y, 
                        epochs=hp["epochs"], 
                        batch_size=hp["batch_size"], 
                        validation_split=0.25,
                        callbacks=[mc, es, tb],
                        )
    return model

# %%
start_time = time.time()
model = train(x_train, y_train, hp)
model_path = "../../model/model.h5"
model.save(model_path)

print(datetime.datetime.now())
print(str(datetime.timedelta(seconds=time.time()-start_time)).split(".")[0])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 10, 128)           12800000
#
#  spatial_dropout1d_1 (Spatia  (None, 10, 128)          0
#  lDropout1D)
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 12,849,538
# Trainable params: 12,849,538
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 766/766 [==============================] - ETA: 0s - loss: 0.3995 - accuracy: 0.8060WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 85s 108ms/step - loss: 0.3995 - accuracy: 0.8060 - val_loss: 0.3349 - val_accuracy: 0.8386
# Epoch 2/100
# 766/766 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8448WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 82s 107ms/step - loss: 0.3269 - accuracy: 0.8448 - val_loss: 0.3105 - val_accuracy: 0.8545
# Epoch 3/100
# 766/766 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8586WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 77s 100ms/step - loss: 0.2987 - accuracy: 0.8586 - val_loss: 0.2854 - val_accuracy: 0.8674
# Epoch 4/100
# 766/766 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.8703WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 77s 100ms/step - loss: 0.2792 - accuracy: 0.8703 - val_loss: 0.2666 - val_accuracy: 0.8774
# Epoch 5/100
# 766/766 [==============================] - ETA: 0s - loss: 0.2619 - accuracy: 0.8807WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 77s 101ms/step - loss: 0.2619 - accuracy: 0.8807 - val_loss: 0.2534 - val_accuracy: 0.8824
# Epoch 6/100
# 766/766 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.8851WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 76s 100ms/step - loss: 0.2484 - accuracy: 0.8851 - val_loss: 0.2449 - val_accuracy: 0.8862
# Epoch 7/100
# 766/766 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.8901WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 78s 102ms/step - loss: 0.2374 - accuracy: 0.8901 - val_loss: 0.2316 - val_accuracy: 0.8931
# Epoch 8/100
# 766/766 [==============================] - ETA: 0s - loss: 0.2271 - accuracy: 0.8964WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 81s 105ms/step - loss: 0.2271 - accuracy: 0.8964 - val_loss: 0.2319 - val_accuracy: 0.8920
# Epoch 9/100
# 766/766 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.8990WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] -
100
# 766/766 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9239WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 82s 108ms/step - loss: 0.1668 - accuracy: 0.9239 - val_loss: 0.1999 - val_accuracy: 0.9108
# Epoch 31/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9234WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 80s 104ms/step - loss: 0.1655 - accuracy: 0.9234 - val_loss: 0.1969 - val_accuracy: 0.9115
# Epoch 32/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.9253WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 79s 103ms/step - loss: 0.1634 - accuracy: 0.9253 - val_loss: 0.1984 - val_accuracy: 0.9110
# Epoch 33/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9247WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 83s 109ms/step - loss: 0.1623 - accuracy: 0.9247 - val_loss: 0.1979 - val_accuracy: 0.9109
# Epoch 34/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9244WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 81s 105ms/step - loss: 0.1616 - accuracy: 0.9244 - val_loss: 0.1960 - val_accuracy: 0.9112
# Epoch 35/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9267WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 82s 107ms/step - loss: 0.1606 - accuracy: 0.9267 - val_loss: 0.1985 - val_accuracy: 0.9099
# Epoch 36/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.9261WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 78s 102ms/step - loss: 0.1605 - accuracy: 0.9261 - val_loss: 0.1960 - val_accuracy: 0.9107
# Epoch 37/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9251WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 76s 99ms/step - loss: 0.1600 - accuracy: 0.9251 - val_loss: 0.1988 - val_accuracy: 0.9136
# Epoch 38/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1579 - accuracy: 0.9276WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 79s 103ms/step - loss: 0.1579 - accuracy: 0.9276 - val_loss: 0.1995 - val_accuracy: 0.9124
# Epoch 39/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9282WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 79s 102ms/step - loss: 0.1556 - accuracy: 0.9282 - val_loss: 0.1993 - val_accuracy: 0.9102
# Epoch 40/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9275WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 79s 103ms/step - loss: 0.1561 - accuracy: 0.9275 - val_loss: 0.2015 - val_accuracy: 0.9121
# Epoch 41/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1554 - accuracy: 0.9287WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 81s 105ms/step - loss: 0.1554 - accuracy: 0.9287 - val_loss: 0.2004 - val_accuracy: 0.9118
# Epoch 42/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9284WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 86s 113ms/step - loss: 0.1550 - accuracy: 0.9284 - val_loss: 0.2007 - val_accuracy: 0.9112
# Epoch 43/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9303WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 82s 108ms/step - loss: 0.1532 - accuracy: 0.9303 - val_loss: 0.2001 - val_accuracy: 0.9118
# Epoch 44/100
# 766/766 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9299WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 766/766 [==============================] - 84s 110ms/step - loss: 0.1535 - accuracy: 0.9299 - val_loss: 0.1972 - val_accuracy: 0.9112
# Epoch 44: early stopping
# 2023-07-04 16:38:42.550831
# 0:59:05

# %%
y_test_arg = np.argmax(y_test, axis=1)
y_pred = np.argmax(model.predict(x_test), axis=1)
# Out:
# 511/511 [==============================] - 1s 1ms/step

# %%
from sklearn.metrics import *
print(classification_report(y_test_arg, y_pred))
print('acc:', round(accuracy_score(y_test_arg, y_pred),3))
print('precision:', round(precision_score(y_test_arg, y_pred, average='weighted'),3))
print('recall:', round(recall_score(y_test_arg, y_pred, average='weighted'),3))
print('f1-score:', round(f1_score(y_test_arg, y_pred, average='weighted'),3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89      6913
#            1       0.91      0.94      0.92      9409
#
#     accuracy                           0.91     16322
#    macro avg       0.91      0.91      0.91     16322
# weighted avg       0.91      0.91      0.91     16322
#
# acc: 0.911
# precision: 0.911
# recall: 0.911
# f1-score: 0.911
